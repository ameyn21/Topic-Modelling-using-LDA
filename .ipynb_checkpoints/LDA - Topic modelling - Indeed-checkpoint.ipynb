# %% [markdown]
# ## Topic Modelling using LDA

# %% [markdown]
# ### In the previous notebook (https://github.com/ameyn21/Clustering-Documents-using-K-means/blob/master/Clustering_of_jobs_using_K_means_8_clusters_Indeed.ipynb) we performed K-means clustering on a set of job description to get 8 clusters of documents.
#
# ### We will perform Topic Modelling on these 8 clusters to know more about these clusters

# %% [markdown]
# ### 1) Import neccesary libraries

# %%
import ast
import re
import nltk 
import numpy as np 
from nltk.corpus import stopwords # Filter out stopwords, such as 'the', 'or', 'and'
import pandas as pd
import matplotlib.pyplot as plt
import gensim
from gensim.utils import simple_preprocess
from wordcloud import WordCloud
from collections import Counter

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\amey.naik\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### 2) Loading the dataset

# %%
df_jobs = pd.read_csv("C:\Data_Science_Lab\Github\Clustering-Documents-using-K-means\job_scrapping_indeed.csv")

# %%
df_jobs.head()
# Out:
#    Unnamed: 0                               job_title  \
# 0           1  Data Scientist, Analytics, BI Engineer
# 1           2                          Data Scientist
# 2           3               Machine Learning Engineer
# 3           4               Sr. Clinical Data Analyst
# 4           5                            Data Analyst
#
#                     company_name  \
# 0             RAACOM Infosystems
# 1  Amazon Dev Center India - Hyd
# 2          WAVELABS TECHNOLOGIES
# 3                      Makrocare
# 4                  GE Appliances
#
#                                          description
# 0  ['spark', 'title', 'large', 'intelligence', 'j...
# 1  ['spark', 'title', 'world', 'large', 'intellig...
# 2  ['classification', 'title', 'reinvent', 'ourse...
# 3  ['planning', 'title', 'device', 'excellent', '...
# 4  ['title', 'made', 'excellent', 'amounts', 'sta...

# %% [markdown]
# #### Let us work with the "description_" column which is a cleaned (pre-processed) version of the "description" column.

# %%
wpt = nltk.WordPunctTokenizer()
tokenized_corpus = [ast.literal_eval(df_jobs['description'][ind]) for ind in df_jobs.index]

# %% [markdown]
# ### 3) Bag of words on the dataset

# %%
dictionary = gensim.corpora.Dictionary(tokenized_corpus)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in tokenized_corpus]

# %% [markdown]
# ### 4) Running LDA on Bag of words corpus

# %%
'''
Train your lda model using gensim.models.LdaMulticore and save it to 'lda_model'
'''
# TODO
lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 20, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %% [markdown]
# ### 5) Generate wordcloud's of all the topics in each clusters

# %%
def Generate_Wordcloud_For_Each_Cluster(wpt, num_clusters):
    for i in range(num_clusters):
        df_docs = df_jobs[df_jobs['ClusterLabel_kmeans'] == i]
        tokenized_corpus = [wpt.tokenize(df_docs['description_'][ind]) for ind in df_docs.index]
        dictionary = gensim.corpora.Dictionary(tokenized_corpus)
        bow_corpus = [dictionary.doc2bow(doc) for doc in tokenized_corpus]

        lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                       num_topics = 5, 
                                       id2word = dictionary,                                    
                                       passes = 10,
                                       workers = 2)


        dict_of_topics = Counter({})
        for topic in range(lda_model.num_topics):
            dict_of_topics = dict_of_topics + Counter(dict(lda_model.show_topic(topic, 20)))

        plt.figure()
        plt.imshow(WordCloud().fit_words(dict(dict_of_topics)))
        plt.axis("off")
        plt.title("Topics for cluster #" + str(i))

# %%
wpt = nltk.WordPunctTokenizer()
Generate_Wordcloud_For_Each_Cluster(wpt, 8)

# %% [markdown]
# **Terms in various clusters:**
#
# **cluster 0**:
# learning, data, using, ai, python, algorithms, working, deep, machine, live, supervised, unsupervised,  analytics,
# opencv, like, computer, libraries, keras, pandas, vision, concepts, science
#
#
#
# **cluster 1:**
# data, project, working ,research, shall, work, application, social, media, user, manage, time ,prepare, work, need,
# us, apply, structural, drawings, design, safety, day, two, report, taking, client, site, work, interior, responsible
#
#
#
# **cluster 2:**
# day, to, include, responsibilities, intern ,selected, day, data ,school, students ,python, teaching, machine, learning,
# labeling, building ,analysis, detection, sentimental, topic, classifiers, testing
#
#
#
# **cluster 3:**
# work, data, projects, develop, ai, model, automation, product ,development, understand, text, team, engage, business,
# defined, client, technical, issues, support, marketing, models, researching, algorithms, chatbots, using, requirements, create
#
#
#
# **cluster 4:**
# data, using, reports, statistical, systems, work, business, analyze, algorithms, designing, analysis, developing, analyzing ,using, patterns, machine, results, research ,complex, models, enhancing, non, presenting, data, create, working, analytical, visualization, strategic, develop, machine, learning, various, tools
#
#
#
# **cluster 5:**
# preparing, various, knowledge,  work ,software ,document, testing, requirement, team, project, requirements, information ,business, clients, projects, reports, market, analysis, data, processes, power, bi, research, course, online, problems ,understanding
#
#
#
# **cluster 6:**
# learning, using, deep, neural, machine, research, work, programs, ai, ml, data, algorithms, spearheading, including, documentation, combining, working, computing, cognitive, models, analysis ,development, language, training, processing, text, web, handling, network, building ,like
#
#
#
# **cluster 7:**
# working, data, learning, etc, pandas, tensorflow, like, python, working, based ,training, models, conduct, ml, ai, day ,meaningful, js, dimensions , need, to, work, machine, end
